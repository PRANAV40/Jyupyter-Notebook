# %%
from PIL import Image
import rembg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-181dc81a6e4b> in <module>
#       1 from PIL import Image
# ----> 2 import rembg
#
# ModuleNotFoundError: No module named 'rembg'

# %%
# !pip install rembg
# Out:
# Unable to create process using 'C:\Users\Pranav mishra\anaconda3\python.exe "C:\Users\Pranav mishra\anaconda3\Scripts\pip-script.py" install rembg'

# %%
img = Image.open('Virat.png')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x576 at 0x1C71AD4B370>

# %%
img_bg_removed = rembg.remove(img)
img_bg_removed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3d2dbb22f27d> in <module>
# ----> 1 img_bg_removed = rembg.remove(img)
#       2 img_bg_removed
#
# NameError: name 'rembg' is not defined
