# %%
import matplotlib.pyplot as plt

x = ['A', 'B', 'C', 'D', 'E']
y = [22, 9, 40, 27, 55]
plt.title("Socre of Batsman in an Ining")
plt.bar(x, y)
plt.xlabel('Batsman Name')
plt.ylabel('Score')

plt.show()

# %%
import matplotlib.pyplot as plt

x = ['April','May','June','July','August','September']
y = [1.67,1.42,1.47,1.48,1.56,1.47]
plt.title("GST Collection in a Months")
#plt.bar(x, y)
plt.plot(x,y,'-.')
plt.xlabel('Months')
plt.ylabel('Total GST Collection in Lakh crore ')

plt.show()

# %%
x = ['April','May','June','July','August','September']
y = [1.67,1.42,1.47,1.48,1.56,1.47]
plt.title("GST Collection in a Months")
plt.bar(x, y)
plt.xlabel('Months')
plt.ylabel('Total GST Collection in Lakh crore ')

plt.show()

# %%
import matplotlib.pyplot as plt

x = ['April','May','June','July','August','September']
y = [1.67,1.42,1.47,1.48,1.56,1.47]
plt.title("GST Collection in a Months")
#plt.bar(x, y)
plt.plot(x,y,'o')
plt.xlabel('Months')
plt.ylabel('Total GST Collection in Lakh crore ')

plt.show()
