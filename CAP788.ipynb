# %%
import pandas as pd
dfPranav = pd.read_csv('DataFrame_Pranav.csv')

# %%
dfPranav.head()
# Out:
#    Duration Pulse Maxpulse  Calories
# 0        60   110      130     409.1
# 1        60   117      145     479.0
# 2        60   103      135     340.0
# 3        45   109      175     282.4
# 4        45   117      148     406.0

# %%
dfPranav.notnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        True   True      True      True
# 1        True   True      True      True
# 2        True   True      True      True
# 3        True   True      True      True
# 4        True   True      True      True
# ..        ...    ...       ...       ...
# 164      True   True      True      True
# 165      True   True      True      True
# 166      True   True      True      True
# 167      True   True      True      True
# 168      True   True      True      True
#
# [169 rows x 4 columns]

# %%
pd.DataFrame(dfPranav)
# Out:
#      Duration Pulse Maxpulse  Calories
# 0          60   110      130     409.1
# 1          60   117      145     479.0
# 2          60   103      135     340.0
# 3          45   109      175     282.4
# 4          45   117      148     406.0
# ..        ...   ...      ...       ...
# 164        60   105      140     290.8
# 165        60            145     300.0
# 166        60   115      145     310.2
# 167        75   120      150     320.4
# 168        75   125      150     330.4
#
# [169 rows x 4 columns]

# %%
dfPranav = dfPranav.replace(to_replace="NaN",
                value=avg)
dfPranav
# Out:
#      Duration Pulse Maxpulse  Calories
# 0          60   110      130     409.1
# 1          60   117      145     479.0
# 2          60   103      135     340.0
# 3          45   109      175     282.4
# 4          45   117      148     406.0
# ..        ...   ...      ...       ...
# 164        60   105      140     290.8
# 165        60            145     300.0
# 166        60   115      145     310.2
# 167        75   120      150     320.4
# 168        75   125      150     330.4
#
# [169 rows x 4 columns]

# %%
dfPranav['Pulse'] = dfPranav['Pulse'].map({'M': 0,
                                 'F': 1, }).astype(float)
dfPranav
# Out:
#      Duration  Pulse Maxpulse  Calories
# 0          60    NaN      130     409.1
# 1          60    NaN      145     479.0
# 2          60    NaN      135     340.0
# 3          45    NaN      175     282.4
# 4          45    NaN      148     406.0
# ..        ...    ...      ...       ...
# 164        60    NaN      140     290.8
# 165        60    NaN      145     300.0
# 166        60    NaN      145     310.2
# 167        75    NaN      150     320.4
# 168        75    NaN      150     330.4
#
# [169 rows x 4 columns]

# %%
dfPranav = dfPranav[dfPranav['Calories'] >= 375]
dfPranav = dfPranav.drop(['Duration'], axis=1)
dfPranav
# Out:
#      Pulse Maxpulse  Calories
# 0      NaN      130     409.1
# 1      NaN      145     479.0
# 4      NaN      148     406.0
# 13     NaN      132     379.3
# 29     NaN      129     380.3
# 35     NaN      140     415.0
# 43     NaN      138     400.0
# 44     NaN      131     397.0
# 46     NaN      153     387.6
# 49     NaN      139     397.6
# 50     NaN      136     380.2
# 51     NaN      146     643.1
# 53     NaN      151     486.0
# 55     NaN      146     450.7
# 56     NaN      121     413.0
# 60     NaN      160    1376.0
# 61     NaN      137    1034.4
# 62     NaN      135     853.0
# 65     NaN      130     800.4
# 66     NaN      135     873.4
# 67     NaN      130     816.0
# 69     NaN      143    1500.2
# 70     NaN      129    1115.0
# 71     NaN      153     387.6
# 72     NaN      127     700.0
# 73     NaN      127     953.2
# 75     NaN      125     563.2
# 78     NaN      130     500.4
# 79     NaN      131    1729.0
# 83     NaN      130     500.0
# ...

# %%
dfPranav.describe()
# Out:
#        Pulse     Calories
# count    0.0    48.000000
# mean     NaN   639.983333
# std      NaN   361.690213
# min      NaN   379.300000
# 25%      NaN   400.000000
# 50%      NaN   493.000000
# 75%      NaN   800.325000
# max      NaN  1860.400000

# %%
dfPranav.isnull()
# Out:
#      Pulse  Maxpulse  Calories
# 0     True     False     False
# 1     True     False     False
# 4     True     False     False
# 13    True     False     False
# 29    True     False     False
# 35    True     False     False
# 43    True     False     False
# 44    True     False     False
# 46    True     False     False
# 49    True     False     False
# 50    True     False     False
# 51    True     False     False
# 53    True     False     False
# 55    True     False     False
# 56    True     False     False
# 60    True     False     False
# 61    True     False     False
# 62    True     False     False
# 65    True     False     False
# 66    True     False     False
# 67    True     False     False
# 69    True     False     False
# 70    True     False     False
# 71    True     False     False
# 72    True     False     False
# 73    True     False     False
# 75    True     False     False
# 78    True     False     False
# 79    True     False     False
# ...

# %%
dfPranav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 158
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pulse     0 non-null      float64
#  1   Maxpulse  48 non-null     object
#  2   Calories  48 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.5+ KB

# %%
dfPranav.hist(grid=False, edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'Pulse'}>,
#         <AxesSubplot:title={'center':'Calories'}>]], dtype=object)

# %%
dfPranav.boxplot(grid=False)
# Out:
# <AxesSubplot:>

# %%
dfPranav.corr()
# Out:
#           Pulse  Calories
# Pulse       NaN       NaN
# Calories    NaN       1.0

# %%
dfPranav.isnull().sum()
# Out:
# Pulse       48
# Maxpulse     0
# Calories     0
# dtype: int64
